# %% [markdown]
# Dependency check and load huggingface scripts

# %%
# !cd /content/
# !git clone https://github.com/huggingface/diffusers.git
# !pip install ./diffusers
# !pip install -U -r /content/diffusers/examples/text_to_image/requirements.txt
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 48352, done.
# remote: Counting objects: 100% (13171/13171), done.
# remote: Compressing objects: 100% (899/899), done.
# remote: Total 48352 (delta 12714), reused 12381 (delta 12222), pack-reused 35181
# Receiving objects: 100% (48352/48352), 31.41 MiB | 31.57 MiB/s, done.
# Resolving deltas: 100% (35993/35993), done.
# Processing ./diffusers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.25.0.dev0) (7.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.25.0.dev0) (3.13.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.25.0.dev0) (0.19.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers==0.25.0.dev0) (1.23.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.25.0.dev0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers==0.25.0.dev0) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.25.0.dev0) (0.4.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers==0.25.0.dev0) (9.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->diffusers==0.25.0.dev0) (2023.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->diffusers==0.25.0.dev0) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->diffusers==0.25.0.dev0) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->diffusers==0.25.0.dev0) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->diffusers==0.25.0.dev0) (23.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.25.0.dev0) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.25.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.25.0.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.25.0.dev0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.25.0.dev0) (2023.11.17)
# Building wheels for collected packages: diffusers
#   Building wheel for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.25.0.dev0-py3-none-any.whl size=1821788 sha256=1681407d6d9ad289cfb138aa856c7ab97f1a3e3bb93958f641bb8aeb5afa8f02
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qffl4m1x/wheels/95/c5/3b/e1b4269f8a2584de57e75f949a185b48fc4144e9a91fc9965a
# Successfully built diffusers
# Installing collected packages: diffusers
# Successfully installed diffusers-0.25.0.dev0
# Collecting accelerate>=0.16.0 (from -r /content/diffusers/examples/text_to_image/requirements.txt (line 1))
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from -r /content/diffusers/examples/text_to_image/requirements.txt (line 2)) (0.16.0+cu121)
# Collecting torchvision (from -r /content/diffusers/examples/text_to_image/requirements.txt (line 2))
#   Downloading torchvision-0.16.2-cp310-cp310-manylinux1_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 33.6 MB/s eta 0:00:00
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/diffusers/examples/text_to_image/requirements.txt (line 3)) (4.35.2)
# Collecting transformers>=4.25.1 (from -r /content/diffusers/examples/text_to_image/requirements.txt (line 3))
#   Downloading transformers-4.36.1-py3-none-any.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 88.0 MB/s eta 0:00:00
# Collecting datasets (from -r /content/diffusers/examples/text_to_image/requirements.txt (line 4))
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 48.6 MB/s eta 0:00:00
# Collecting ftfy (from -r /content/diffusers/examples/text_to_image/requirements.txt (line 5))
#   Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from -r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (2.15.1)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.10/dist-packages (from -r /content/diffusers/examples/text_to_image/requirements.txt (line 7)) (3.1.2)
# Collecting peft==0.7.0 (from -r /content/diffusers/examples/text_to_image/requirements.txt (line 8))
#   Downloading peft-0.7.0-py3-none-any.whl (168 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 25.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8)) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8)) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8)) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8)) (2.1.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8)) (4.66.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8)) (0.4.1)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8)) (0.19.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision->-r /content/diffusers/examples/text_to_image/requirements.txt (line 2)) (2.31.0)
# Collecting torch>=1.13.0 (from peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8))
#   Downloading torch-2.1.2-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->-r /content/diffusers/examples/text_to_image/requirements.txt (line 2)) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8)) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8)) (3.2.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8)) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 69.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 74.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 95.8 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8))
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.7 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 29.8 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.6 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.2 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.18.1 (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8))
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 4.5 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8)) (2.1.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8))
#   Downloading nvidia_nvjitlink_cu12-12.3.101-py3-none-manylinux1_x86_64.whl (20.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 94.1 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->-r /content/diffusers/examples/text_to_image/requirements.txt (line 3)) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->-r /content/diffusers/examples/text_to_image/requirements.txt (line 3)) (0.15.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (10.0.1)
# Collecting pyarrow-hotfix (from datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4))
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4))
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (3.4.1)
# Collecting multiprocess (from datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4))
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 23.5 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (3.9.1)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy->-r /content/diffusers/examples/text_to_image/requirements.txt (line 5)) (0.2.12)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (1.60.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (3.5.1)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2->-r /content/diffusers/examples/text_to_image/requirements.txt (line 7)) (2.1.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (4.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->-r /content/diffusers/examples/text_to_image/requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->-r /content/diffusers/examples/text_to_image/requirements.txt (line 2)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->-r /content/diffusers/examples/text_to_image/requirements.txt (line 2)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->-r /content/diffusers/examples/text_to_image/requirements.txt (line 2)) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->-r /content/diffusers/examples/text_to_image/requirements.txt (line 4)) (2023.3.post1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->-r /content/diffusers/examples/text_to_image/requirements.txt (line 6)) (3.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->peft==0.7.0->-r /content/diffusers/examples/text_to_image/requirements.txt (line 8)) (1.3.0)
# Installing collected packages: pyarrow-hotfix, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, ftfy, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, transformers, torch, datasets, torchvision, accelerate, peft
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0+cu121
#     Uninstalling torch-2.1.0+cu121:
#       Successfully uninstalled torch-2.1.0+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.16.0+cu121
#     Uninstalling torchvision-0.16.0+cu121:
#       Successfully uninstalled torchvision-0.16.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# Successfully installed accelerate-0.25.0 datasets-2.15.0 dill-0.3.7 ftfy-6.1.3 multiprocess-0.70.15 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.3.101 nvidia-nvtx-cu12-12.1.105 peft-0.7.0 pyarrow-hotfix-0.6 torch-2.1.2 torchvision-0.16.2 transformers-4.36.1

# %% [markdown]
# Check GPU avalibility

# %%
# !nvidia-smi
# Out:
# Sun Dec 17 03:47:37 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0              26W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# Setup accelerate config for lora model
#
# > In regular text-to-image model, "--mixed_precision" can be added to accelerate traning speed as well as lower the memory use. E.g. !accelerate config default --mixed_precision fp16

# %%
# !accelerate config default
# Out:
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %% [markdown]
# Login huggingface accont and setup base model, dataset and output path.

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import os

os.environ['MODEL_NAME'] = f'runwayml/stable-diffusion-v1-5'
os.environ['DATASET_NAME'] = f'jwl25b/final_project_dataset'
os.environ['OUTPUT_DIR'] = f'testModelSDv1-2'

# %% [markdown]
# Training model. In this case, we are training lora adapter.
#
#
#
#
# > Be sure to run it in colab pro with high RAM, otherwise would be error due to insufficient memory.
#
#
# Config of train_batch_size, num_train_epochs might various depend on different hardware:
#
#
#
# 1. T4 with 15GB GPU RAM
# 2. V100 with 16GB GPU RAM
# 3. A100 with 40GB GPU RAM

# %%
# !accelerate launch diffusers/examples/text_to_image/train_text_to_image_lora.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --dataset_name=$DATASET_NAME \
  --dataloader_num_workers=8 \
  --resolution=512 --center_crop --random_flip \
  --gradient_accumulation_steps=4 \
  --gradient_checkpointing \
  --train_batch_size=7 \
  --num_train_epochs=400 \
  --learning_rate=1e-04 \
  --lr_scheduler="cosine" --lr_warmup_steps=0\
  --validation_prompt="Tommy Hilfiger men's top fashion product"\
  --validation_epochs=50 \
  --push_to_hub \
  --output_dir=$OUTPUT_DIR

# For regular text-to-image model, use:
#!accelerate launch diffusers/examples/text_to_image/train_text_to_image.py \
#  --pretrained_model_name_or_path=$MODEL_NAME \
#  --dataset_name=$DATASET_NAME \
#  --use_ema \
#  --resolution=512 --center_crop --random_flip \
#  --train_batch_size=1 \
#  --gradient_accumulation_steps=4 \
#  --gradient_checkpointing \
#  --mixed_precision="fp16" \
#  --max_train_steps=300 \
#  --learning_rate=1e-05 \
#  --max_grad_norm=1 \
#  --push_to_hub \
#  --checkpointing_steps=100000 \
#  --lr_scheduler="constant" \
#  --lr_warmup_steps=0 \
#  --output_dir=$OUTPUT_DIR
# Out:
# 2023-12-17 04:12:47.046596: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 04:12:47.046649: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 04:12:47.047881: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 04:12:48.218732: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 12/17/2023 04:12:48 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: no
#
# {'thresholding', 'timestep_spacing', 'clip_sample_range', 'variance_type', 'dynamic_thresholding_ratio', 'prediction_type', 'sample_max_value'} was not found in config. Values will be initialized to default values.
# {'force_upcast', 'scaling_factor'} was not found in config. Values will be initialized to default values.
# {'time_embedding_type', 'class_embed_type', 'projection_class_embeddings_input_dim', 'class_embeddings_concat', 'num_class_embeds', 'conv_out_kernel', 'encoder_hid_dim', 'dropout', 'num_attention_heads', 'addition_embed_type', 'attention_type', 'dual_cross_attention', 'use_linear_projection', 'addition_embed_type_num_heads', 'reverse_transformer_layers_per_block', 'upcast_attention', 'only_cross_attention', 'time_embedding_dim', 'addition_time_embed_dim', 'mid_block_type', 'transformer_layers_per_block', 'mid_block_only_cross_attention', 'time_cond_proj_dim', 'encoder_hid_dim_type', 'resnet_out_scale_factor', 'resnet_time_scale_shift', 'timestep_post_act', 'cross_attention_norm', 'time_embedding_act_fn', 'conv_in_kernel', 'resnet_skip_time_act'} was not found in config. Values will be initialized to default values.
# 12/17/2023 04:12:54 - INFO - __main__ - ***** Running training *****
# 12/17/2023 04:12:54 - INFO - __main__ -   Num examples = 50
# 12/17/2023 04:12:54 - INFO - __main__ -   Num Epochs = 400
# 12/17/2023 04:12:54 - INFO - __main__ -   Instantaneous batch size per device = 7
# 12/17/2023 04:12:54 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 28
# 12/17/2023 04:12:54 - INFO - __main__ -   Gradient Accumulation steps = 4
# 12/17/2023 04:12:54 - INFO - __main__ -   Total optimization steps = 800
# Steps:   0% 2/800 [00:14<1:35:02,  7.15s/it, lr=0.0001, step_loss=0.0145]12/17/2023 04:13:09 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Tommy Hilfiger men's top fashion product.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:02,  2.50it/s]{'force_upcast', 'scaling_factor'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.95it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:00<00:00,  7.97it/s]
# Steps:  13% 102/800 [12:04<1:17:49,  6.69s/it, lr=9.6e-5, step_loss=0.0214]12/17/2023 04:24:59 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Tommy Hilfiger men's top fashion product.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:02,  2.61it/s]{'force_upcast', 'scaling_factor'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.93it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:00<00:00,  8.00it/s]
# Steps:  25% 202/800 [23:56<1:06:48,  6.70s/it, lr=8.51e-5, step_loss=0.00357]12/17/2023 04:36:51 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Tommy Hilfiger men's top fashion product.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:02,  2.43it/s]{'force_upcast', 'scaling_factor'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.91it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:00<00:00,  7.90it/s]
# Steps:  38% 302/800 [35:49<55:54,  6.74s/it, lr=6.88e-5, step_loss=0.0115]12/17/2023 04:48:44 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Tommy Hilfiger men's top fashion product.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:02,  2.52it/s]{'force_upcast', 'scaling_factor'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:00,  4.07it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:00<00:00,  8.20it/s]
# Steps:  50% 402/800 [47:44<44:44,  6.75s/it, lr=4.96e-5, step_loss=0.00135]12/17/2023 05:00:38 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Tommy Hilfiger men's top fashion product.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:02,  2.50it/s]{'force_upcast', 'scaling_factor'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.95it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:00<00:00,  8.00it/s]
# Steps:  62% 500/800 [59:24<33:32,  6.71s/it, lr=3.1e-5, step_loss=0.0651]12/17/2023 05:12:19 - INFO - accelerate.accelerator - Saving current state to testModelSDv1-2/checkpoint-500
# 12/17/2023 05:12:36 - INFO - accelerate.checkpointing - Model weights saved in testModelSDv1-2/checkpoint-500/model.safetensors
# 12/17/2023 05:12:36 - INFO - accelerate.checkpointing - Optimizer state saved in testModelSDv1-2/checkpoint-500/optimizer.bin
# 12/17/2023 05:12:36 - INFO - accelerate.checkpointing - Scheduler state saved in testModelSDv1-2/checkpoint-500/scheduler.bin
# 12/17/2023 05:12:36 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in testModelSDv1-2/checkpoint-500/sampler.bin
# 12/17/2023 05:12:36 - INFO - accelerate.checkpointing - Random states saved in testModelSDv1-2/checkpoint-500/random_states_0.pkl
# Model weights saved in testModelSDv1-2/checkpoint-500/pytorch_lora_weights.safetensors
# 12/17/2023 05:12:36 - INFO - __main__ - Saved state to testModelSDv1-2/checkpoint-500
# Steps:  63% 502/800 [59:56<52:02, 10.48s/it, lr=3.05e-5, step_loss=0.0649]12/17/2023 05:12:51 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Tommy Hilfiger men's top fashion product.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:02,  2.26it/s]{'force_upcast', 'scaling_factor'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.84it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:00<00:00,  7.72it/s]
# Steps:  75% 602/800 [1:12:09<22:47,  6.91s/it, lr=1.44e-5, step_loss=0.00211]12/17/2023 05:25:03 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Tommy Hilfiger men's top fashion product.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:02,  2.61it/s]{'force_upcast', 'scaling_factor'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:00,  4.17it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:00<00:00,  8.42it/s]
# Steps:  88% 702/800 [1:24:19<11:14,  6.89s/it, lr=3.66e-6, step_loss=0.00468]12/17/2023 05:37:14 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: Tommy Hilfiger men's top fashion product.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:02,  2.36it/s]{'force_upcast', 'scaling_factor'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.75it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:00<00:00,  7.60it/s]
# Steps: 100% 800/800 [1:36:17<00:00,  6.90s/it, lr=0, step_loss=0.00803]      Model weights saved in testModelSDv1-2/pytorch_lora_weights.safetensors
#
# model.safetensors:   0% 0.00/3.44G [00:00<?, ?B/s]
#
# optimizer.bin:   0% 0.00/6.59M [00:00<?, ?B/s]
#
#
# pytorch_lora_weights.safetensors:   0% 0.00/3.23M [00:00<?, ?B/s]
#
#
#
# scheduler.bin:   0% 0.00/1.00k [00:00<?, ?B/s]
#
#
#
#
# Upload 30 LFS files:   0% 0/30 [00:00<?, ?it/s]
#
#
#
#
#
# random_states_0.pkl:   0% 0.00/14.3k [00:00<?, ?B/s]
# model.safetensors:   0% 16.4k/3.44G [00:00<38:22:48, 24.9kB/s]
#
#
# pytorch_lora_weights.safetensors:   1% 16.4k/3.23M [00:00<02:11, 24.5kB/s]
#
# optimizer.bin:   0% 16.4k/6.59M [00:00<04:34, 24.0kB/s]
#
#
#
#
#
# random_states_0.pkl: 100% 14.3k/14.3k [00:00<00:00, 21.1kB/s]
#
#
#
# scheduler.bin: 100% 1.00k/1.00k [00:00<00:00, 1.46kB/s]
# model.safetensors:   0% 2.77M/3.44G [00:00<11:56, 4.80MB/s]
#
#
# pytorch_lora_weights.safetensors:  82% 2.65M/3.23M [00:00<00:00, 4.59MB/s]
#
# random_states_0.pkl: 100% 14.3k/14.3k [00:00<00:00, 16.8kB/s]
#
# model.safetensors:   0% 4.52M/3.44G [00:00<08:41, 6.58MB/s]
#
# optimizer.bin:  68% 4.49M/6.59M [00:00<00:00, 6.29MB/s]
# model.safetensors:   0% 7.82M/3.44G [00:01<05:01, 11.4MB/s]
#
# scheduler.bin: 100% 1.00k/1.00k [00:01<00:00, 891B/s]
#
#
#
#
# events.out.tfevents.1702784963.fb30e7f71057.2133.1:   0% 0.00/2.25k [00:00<?, ?B/s]
# model.safetensors:   0% 10.5M/3.44G [00:01<05:09, 11.1MB/s]
#
#
#
#
#
# events.out.tfevents.1702785027.fb30e7f71057.2513.1:   0% 0.00/2.22k [00:00<?, ?B/s]
# events.out.tfevents.1702784963.fb30e7f71057.2133.1: 100% 2.25k/2.25k [00:00<00:00, 5.57kB/s]
# pytorch_lora_weights.safetensors: 100% 3.23M/3.23M [00:01<00:00, 1.91MB/s]
#
#
#
# events.out.tfevents.1702785027.fb30e7f71057.2513.1: 100% 2.22k/2.22k [00:00<00:00, 5.51kB/s]
# optimizer.bin: 100% 6.59M/6.59M [00:01<00:00, 3.57MB/s]
#
# model.safetensors:   0% 16.0M/3.44G [00:01<06:18, 9.05MB/s]
#
# events.out.tfevents.1702785139.fb30e7f71057.3028.1:   0% 0.00/2.22k [00:00<?, ?B/s]
# model.safetensors:   1% 30.7M/3.44G [00:02<02:00, 28.3MB/s]
#
#
#
# events.out.tfevents.1702785264.fb30e7f71057.3560.1:   0% 0.00/2.22k [00:00<?, ?B/s]
#
#
#
#
#
# events.out.tfevents.1702785115.fb30e7f71057.2908.1: 100% 2.22k/2.22k [00:00<00:00, 5.92kB/s]
#
# events.out.tfevents.1702785343.fb30e7f71057.4174.1: 100% 2.22k/2.22k [00:00<00:00, 14.3kB/s]
# events.out.tfevents.1702785139.fb30e7f71057.3028.1: 100% 2.22k/2.22k [00:00<00:00, 5.81kB/s]
#
#
# events.out.tfevents.1702785264.fb30e7f71057.3560.1: 100% 2.22k/2.22k [00:00<00:00, 5.73kB/s]
# events.out.tfevents.1702785390.fb30e7f71057.4480.1: 100% 2.22k/2.22k [00:00<00:00, 16.8kB/s]
#
#
# events.out.tfevents.1702785709.fb30e7f71057.7614.1:   0% 0.00/2.22k [00:00<?, ?B/s]
#
#
# events.out.tfevents.1702785916.fb30e7f71057.9634.1:   0% 0.00/2.22k [00:00<?, ?B/s]
#
#
#
# events.out.tfevents.1702785709.fb30e7f71057.7614.1: 100% 2.22k/2.22k [00:00<00:00, 18.4kB/s]
# events.out.tfevents.1702785916.fb30e7f71057.9634.1: 100% 2.22k/2.22k [00:00<00:00, 16.9kB/s]
#
#
# events.out.tfevents.1702785945.fb30e7f71057.9862.1: 100% 2.22k/2.22k [00:00<00:00, 16.6kB/s]
#
# model.safetensors:   1% 42.3M/3.44G [00:02<03:13, 17.6MB/s]
#
#
# events.out.tfevents.1702786374.fb30e7f71057.13719.1:   0% 0.00/2.22k [00:00<?, ?B/s]
#
#
#
# events.out.tfevents.1702784963.fb30e7f71057.2133.0:   0% 0.00/280 [00:00<?, ?B/s]
#
#
#
#
#
# events.out.tfevents.1702786374.fb30e7f71057.13719.1: 100% 2.22k/2.22k [00:00<00:00, 16.5kB/s]
#
# events.out.tfevents.1702784963.fb30e7f71057.2133.0: 100% 280/280 [00:00<00:00, 1.42kB/s]
# events.out.tfevents.1702786314.fb30e7f71057.13348.1: 100% 2.22k/2.22k [00:00<00:00, 5.37kB/s]
#
#
# events.out.tfevents.1702785115.fb30e7f71057.2908.0:   0% 0.00/88.0 [00:00<?, ?B/s]
#
#
# events.out.tfevents.1702785139.fb30e7f71057.3028.0:   0% 0.00/1.62M [00:00<?, ?B/s]
# events.out.tfevents.1702785115.fb30e7f71057.2908.0: 100% 88.0/88.0 [00:00<00:00, 643B/s]
#
# events.out.tfevents.1702785139.fb30e7f71057.3028.0: 100% 1.62M/1.62M [00:00<00:00, 8.93MB/s]
#
#
# events.out.tfevents.1702785027.fb30e7f71057.2513.0: 100% 1.65M/1.65M [00:00<00:00, 2.63MB/s]
#
#
#
# events.out.tfevents.1702785343.fb30e7f71057.4174.0:   0% 0.00/232 [00:00<?, ?B/s]
#
#
#
# events.out.tfevents.1702785343.fb30e7f71057.4174.0: 100% 232/232 [00:00<00:00, 1.79kB/s]
#
#
#
# events.out.tfevents.1702785709.fb30e7f71057.7614.0:   0% 0.00/1.62M [00:00<?, ?B/s]
# events.out.tfevents.1702785390.fb30e7f71057.4480.0: 100% 1.62M/1.62M [00:00<00:00, 7.88MB/s]
#
#
#
#
# events.out.tfevents.1702785916.fb30e7f71057.9634.0:   0% 0.00/280 [00:00<?, ?B/s]
#
#
#
#
#
# events.out.tfevents.1702785945.fb30e7f71057.9862.0:   0% 0.00/1.62M [00:00<?, ?B/s]
# events.out.tfevents.1702785264.fb30e7f71057.3560.0: 100% 1.60M/1.60M [00:00<00:00, 2.49MB/s]
#
#
# events.out.tfevents.1702785916.fb30e7f71057.9634.0: 100% 280/280 [00:00<00:00, 765B/s]
#
# events.out.tfevents.1702786314.fb30e7f71057.13348.0: 100% 184/184 [00:00<00:00, 1.03kB/s]
#
#
# events.out.tfevents.1702785709.fb30e7f71057.7614.0: 100% 1.62M/1.62M [00:00<00:00, 2.04MB/s]
#
#
# events.out.tfevents.1702786374.fb30e7f71057.13719.0:  81% 8.96M/11.1M [00:00<00:00, 88.2MB/s]
#
#
# pytorch_lora_weights.safetensors:   0% 0.00/3.23M [00:00<?, ?B/s]
# events.out.tfevents.1702785945.fb30e7f71057.9862.0: 100% 1.62M/1.62M [00:00<00:00, 1.73MB/s]
#
# model.safetensors:   3% 94.7M/3.44G [00:05<02:02, 27.3MB/s]
# pytorch_lora_weights.safetensors: 100% 3.23M/3.23M [00:00<00:00, 4.19MB/s]
# events.out.tfevents.1702786374.fb30e7f71057.13719.0: 100% 11.1M/11.1M [00:00<00:00, 11.3MB/s]
#
# model.safetensors:   3% 112M/3.44G [00:05<01:54, 29.1MB/s]
# model.safetensors:   4% 123M/3.44G [00:06<01:53, 29.1MB/s]
# model.safetensors:   4% 127M/3.44G [00:06<01:57, 28.1MB/s]
# model.safetensors:   4% 130M/3.44G [00:06<02:44, 20.1MB/s]
# model.safetensors:   4% 144M/3.44G [00:06<01:39, 33.2MB/s]
# model.safetensors:   4% 149M/3.44G [00:07<02:50, 19.3MB/s]
# model.safetensors:   4% 153M/3.44G [00:07<02:48, 19.5MB/s]
# model.safetensors:   5% 157M/3.44G [00:08<03:31, 15.5MB/s]
# model.safetensors:   5% 160M/3.44G [00:08<04:27, 12.3MB/s]
# model.safetensors:   5% 175M/3.44G [00:08<02:06, 25.9MB/s]
# model.safetensors:   5% 181M/3.44G [00:09<02:19, 23.3MB/s]
# model.safetensors:   6% 192M/3.44G [00:09<02:09, 25.1MB/s]
# model.safetensors:   6% 206M/3.44G [00:09<01:24, 38.4MB/s]
# model.safetensors:   6% 213M/3.44G [00:09<01:34, 34.1MB/s]
# model.safetensors:   7% 224M/3.44G [00:10<01:40, 32.0MB/s]
# model.safetensors:   7% 238M/3.44G [00:10<01:10, 45.6MB/s]
# model.safetensors:   7% 246M/3.44G [00:10<01:30, 35.4MB/s]
# model.safetensors:   7% 256M/3.44G [00:11<01:44, 30.5MB/s]
# model.safetensors:   8% 270M/3.44G [00:11<01:13, 43.2MB/s]
# model.safetensors:   8% 278M/3.44G [00:11<01:26, 36.7MB/s]
# model.safetensors:   8% 288M/3.44G [00:11<01:36, 32.6MB/s]
# model.safetensors:   9% 302M/3.44G [00:12<01:08, 45.6MB/s]
# model.safetensors:   9% 310M/3.44G [00:12<01:17, 40.5MB/s]
# model.safetensors:   9% 320M/3.44G [00:12<01:27, 35.7MB/s]
# model.safetensors:  10% 335M/3.44G [00:12<01:01, 50.8MB/s]
# model.safetensors:  10% 343M/3.44G [00:13<01:14, 41.3MB/s]
# model.safetensors:  10% 352M/3.44G [00:13<01:29, 34.6MB/s]
# model.safetensors:  11% 367M/3.44G [00:13<01:02, 49.3MB/s]
# model.safetensors:  11% 375M/3.44G [00:13<01:11, 43.1MB/s]
# model.safetensors:  11% 384M/3.44G [00:14<01:24, 36.4MB/s]
# model.safetensors:  12% 399M/3.44G [00:14<00:59, 51.2MB/s]
# model.safetensors:  12% 407M/3.44G [00:14<01:10, 43.1MB/s]
# model.safetensors:  12% 416M/3.44G [00:14<01:23, 36.3MB/s]
# model.safetensors:  12% 430M/3.44G [00:15<00:59, 50.3MB/s]
# model.safetensors:  13% 438M/3.44G [00:15<01:18, 38.2MB/s]
# model.safetensors:  13% 448M/3.44G [00:15<01:26, 34.5MB/s]
# model.safetensors:  13% 463M/3.44G [00:15<01:00, 49.0MB/s]
# model.safetensors:  14% 471M/3.44G [00:16<01:14, 39.6MB/s]
# model.safetensors:  14% 480M/3.44G [00:17<02:58, 16.6MB/s]
# model.safetensors:  14% 494M/3.44G [00:17<02:00, 24.5MB/s]
# model.safetensors:  15% 501M/3.44G [00:18<02:02, 24.0MB/s]
# model.safetensors:  15% 512M/3.44G [00:18<01:45, 27.8MB/s]
# model.safetensors:  15% 526M/3.44G [00:18<01:13, 39.9MB/s]
# model.safetensors:  16% 534M/3.44G [00:18<01:20, 36.0MB/s]
# model.safetensors:  16% 544M/3.44G [00:18<01:18, 37.0MB/s]
# model.safetensors:  16% 558M/3.44G [00:19<00:56, 51.2MB/s]
# model.safetensors:  16% 567M/3.44G [00:19<01:10, 40.8MB/s]
# model.safetensors:  17% 576M/3.44G [00:19<01:18, 36.4MB/s]
# model.safetensors:  17% 591M/3.44G [00:19<00:55, 51.4MB/s]
# model.safetensors:  17% 599M/3.44G [00:20<01:04, 44.0MB/s]
# model.safetensors:  18% 608M/3.44G [00:20<01:16, 37.0MB/s]
# model.safetensors:  18% 622M/3.44G [00:20<00:54, 51.6MB/s]
# model.safetensors:  18% 631M/3.44G [00:20<01:13, 38.4MB/s]
# model.safetensors:  19% 640M/3.44G [00:21<01:12, 38.8MB/s]
# model.safetensors:  19% 655M/3.44G [00:21<00:50, 54.9MB/s]
# model.safetensors:  19% 664M/3.44G [00:21<01:06, 42.0MB/s]
# model.safetensors:  20% 672M/3.44G [00:21<01:17, 35.7MB/s]
# model.safetensors:  20% 686M/3.44G [00:22<00:54, 50.1MB/s]
# model.safetensors:  20% 695M/3.44G [00:22<01:05, 42.0MB/s]
# model.safetensors:  20% 704M/3.44G [00:22<01:24, 32.3MB/s]
# model.safetensors:  21% 719M/3.44G [00:22<00:58, 46.4MB/s]
# model.safetensors:  21% 727M/3.44G [00:23<01:06, 41.0MB/s]
# model.safetensors:  21% 736M/3.44G [00:23<01:18, 34.6MB/s]
# model.safetensors:  22% 750M/3.44G [00:23<00:55, 48.2MB/s]
# model.safetensors:  22% 758M/3.44G [00:23<01:06, 40.4MB/s]
# model.safetensors:  22% 768M/3.44G [00:24<01:12, 37.0MB/s]
# model.safetensors:  23% 782M/3.44G [00:24<00:52, 51.0MB/s]
# model.safetensors:  23% 790M/3.44G [00:24<00:59, 44.2MB/s]
# model.safetensors:  23% 800M/3.44G [00:24<01:09, 38.1MB/s]
# model.safetensors:  24% 815M/3.44G [00:25<00:48, 53.7MB/s]
# model.safetensors:  24% 823M/3.44G [00:25<00:58, 44.6MB/s]
# model.safetensors:  24% 832M/3.44G [00:25<01:07, 38.6MB/s]
# model.safetensors:  25% 847M/3.44G [00:25<00:47, 54.6MB/s]
# model.safetensors:  25% 856M/3.44G [00:26<01:25, 30.1MB/s]
# model.safetensors:  25% 864M/3.44G [00:26<01:28, 29.1MB/s]
# model.safetensors:  26% 878M/3.44G [00:26<01:01, 41.6MB/s]
# model.safetensors:  26% 886M/3.44G [00:27<01:12, 35.5MB/s]
# model.safetensors:  26% 896M/3.44G [00:27<01:19, 31.9MB/s]
# model.safetensors:  26% 911M/3.44G [00:27<00:55, 45.7MB/s]
# model.safetensors:  27% 919M/3.44G [00:28<01:05, 38.5MB/s]
# model.safetensors:  27% 928M/3.44G [00:28<01:14, 33.6MB/s]
# model.safetensors:  27% 943M/3.44G [00:28<00:52, 47.8MB/s]
# model.safetensors:  28% 951M/3.44G [00:29<01:27, 28.3MB/s]
# model.safetensors:  28% 960M/3.44G [00:29<01:28, 28.1MB/s]
# model.safetensors:  28% 975M/3.44G [00:29<00:59, 41.3MB/s]
# model.safetensors:  29% 983M/3.44G [00:29<01:13, 33.5MB/s]
# model.safetensors:  29% 992M/3.44G [00:30<01:19, 30.7MB/s]
# model.safetensors:  29% 1.01G/3.44G [00:30<00:54, 44.5MB/s]
# model.safetensors:  29% 1.02G/3.44G [00:30<01:09, 35.1MB/s]
# model.safetensors:  30% 1.02G/3.44G [00:31<01:15, 32.1MB/s]
# model.safetensors:  30% 1.04G/3.44G [00:31<00:53, 45.3MB/s]
# model.safetensors:  30% 1.05G/3.44G [00:31<01:04, 37.1MB/s]
# model.safetensors:  31% 1.06G/3.44G [00:32<01:32, 25.9MB/s]
# model.safetensors:  31% 1.07G/3.44G [00:32<01:02, 37.8MB/s]
# model.safetensors:  31% 1.08G/3.44G [00:32<01:06, 35.4MB/s]
# model.safetensors:  32% 1.09G/3.44G [00:32<01:08, 34.5MB/s]
# model.safetensors:  32% 1.10G/3.44G [00:33<00:47, 48.9MB/s]
# model.safetensors:  32% 1.11G/3.44G [00:33<00:56, 41.2MB/s]
# model.safetensors:  33% 1.12G/3.44G [00:33<01:00, 38.1MB/s]
# model.safetensors:  33% 1.13G/3.44G [00:33<00:43, 53.3MB/s]
# model.safetensors:  33% 1.14G/3.44G [00:33<00:48, 47.8MB/s]
# model.safetensors:  33% 1.15G/3.44G [00:34<00:53, 42.4MB/s]
# model.safetensors:  34% 1.17G/3.44G [00:34<00:39, 57.6MB/s]
# model.safetensors:  34% 1.17G/3.44G [00:34<00:50, 45.2MB/s]
# model.safetensors:  34% 1.18G/3.44G [00:34<01:00, 37.5MB/s]
# model.safetensors:  35% 1.20G/3.44G [00:35<00:42, 53.3MB/s]
# model.safetensors:  35% 1.21G/3.44G [00:35<00:50, 44.5MB/s]
# model.safetensors:  35% 1.22G/3.44G [00:35<01:03, 35.2MB/s]
# model.safetensors:  36% 1.23G/3.44G [00:35<00:43, 50.6MB/s]
# model.safetensors:  36% 1.24G/3.44G [00:36<00:52, 42.3MB/s]
# model.safetensors:  36% 1.25G/3.44G [00:36<00:58, 37.2MB/s]
# model.safetensors:  37% 1.26G/3.44G [00:36<00:41, 52.2MB/s]
# model.safetensors:  37% 1.27G/3.44G [00:36<00:49, 43.8MB/s]
# model.safetensors:  37% 1.28G/3.44G [00:37<01:02, 34.8MB/s]
# model.safetensors:  38% 1.30G/3.44G [00:37<00:43, 49.9MB/s]
# model.safetensors:  38% 1.30G/3.44G [00:37<00:49, 43.2MB/s]
# model.safetensors:  38% 1.31G/3.44G [00:38<01:27, 24.4MB/s]
# model.safetensors:  39% 1.33G/3.44G [00:38<00:59, 35.3MB/s]
# model.safetensors:  39% 1.33G/3.44G [00:38<01:08, 30.6MB/s]
# model.safetensors:  39% 1.34G/3.44G [00:39<01:09, 30.3MB/s]
# model.safetensors:  39% 1.36G/3.44G [00:39<00:48, 43.1MB/s]
# model.safetensors:  40% 1.37G/3.44G [00:39<00:59, 35.1MB/s]
# model.safetensors:  40% 1.38G/3.44G [00:40<01:04, 32.0MB/s]
# model.safetensors:  40% 1.39G/3.44G [00:40<00:44, 45.6MB/s]
# model.safetensors:  41% 1.40G/3.44G [00:40<00:49, 40.9MB/s]
# model.safetensors:  41% 1.41G/3.44G [00:40<00:59, 34.5MB/s]
# model.safetensors:  41% 1.42G/3.44G [00:40<00:41, 48.3MB/s]
# model.safetensors:  42% 1.43G/3.44G [00:41<00:47, 42.1MB/s]
# model.safetensors:  42% 1.44G/3.44G [00:41<00:56, 35.7MB/s]
# model.safetensors:  42% 1.45G/3.44G [00:41<00:39, 50.0MB/s]
# model.safetensors:  42% 1.46G/3.44G [00:41<00:48, 40.8MB/s]
# model.safetensors:  43% 1.47G/3.44G [00:42<00:53, 36.5MB/s]
# model.safetensors:  43% 1.49G/3.44G [00:42<00:38, 50.5MB/s]
# model.safetensors:  43% 1.49G/3.44G [00:42<00:51, 37.8MB/s]
# model.safetensors:  44% 1.50G/3.44G [00:43<00:54, 35.3MB/s]
# model.safetensors:  44% 1.52G/3.44G [00:43<00:39, 48.9MB/s]
# model.safetensors:  44% 1.53G/3.44G [00:43<00:48, 39.2MB/s]
# model.safetensors:  45% 1.54G/3.44G [00:43<00:52, 36.0MB/s]
# model.safetensors:  45% 1.55G/3.44G [00:43<00:37, 49.9MB/s]
# model.safetensors:  45% 1.56G/3.44G [00:44<00:42, 44.0MB/s]
# model.safetensors:  46% 1.57G/3.44G [00:44<00:46, 40.0MB/s]
# model.safetensors:  46% 1.58G/3.44G [00:44<00:34, 54.5MB/s]
# model.safetensors:  46% 1.59G/3.44G [00:44<00:42, 43.6MB/s]
# model.safetensors:  46% 1.60G/3.44G [00:45<00:51, 35.7MB/s]
# model.safetensors:  47% 1.61G/3.44G [00:45<00:36, 49.7MB/s]
# model.safetensors:  47% 1.62G/3.44G [00:45<00:48, 37.9MB/s]
# model.safetensors:  47% 1.63G/3.44G [00:46<00:48, 37.0MB/s]
# model.safetensors:  48% 1.65G/3.44G [00:46<00:35, 51.2MB/s]
# model.safetensors:  48% 1.65G/3.44G [00:46<00:41, 42.9MB/s]
# model.safetensors:  48% 1.66G/3.44G [00:46<00:47, 37.5MB/s]
# model.safetensors:  49% 1.68G/3.44G [00:46<00:34, 51.6MB/s]
# model.safetensors:  49% 1.69G/3.44G [00:47<00:44, 39.1MB/s]
# model.safetensors:  49% 1.70G/3.44G [00:47<00:50, 34.6MB/s]
# model.safetensors:  50% 1.71G/3.44G [00:47<00:35, 48.2MB/s]
# model.safetensors:  50% 1.72G/3.44G [00:48<00:41, 41.5MB/s]
# model.safetensors:  50% 1.73G/3.44G [00:48<00:45, 37.4MB/s]
# model.safetensors:  51% 1.74G/3.44G [00:48<00:32, 52.7MB/s]
# model.safetensors:  51% 1.75G/3.44G [00:48<00:39, 43.1MB/s]
# model.safetensors:  51% 1.76G/3.44G [00:49<00:46, 36.1MB/s]
# model.safetensors:  52% 1.77G/3.44G [00:49<00:33, 50.1MB/s]
# model.safetensors:  52% 1.78G/3.44G [00:49<00:37, 43.9MB/s]
# model.safetensors:  52% 1.79G/3.44G [00:49<00:45, 36.4MB/s]
# model.safetensors:  52% 1.81G/3.44G [00:49<00:32, 50.3MB/s]
# model.safetensors:  53% 1.81G/3.44G [00:50<00:56, 29.0MB/s]
# model.safetensors:  53% 1.82G/3.44G [00:50<00:52, 30.8MB/s]
# model.safetensors:  53% 1.84G/3.44G [00:51<00:36, 43.6MB/s]
# model.safetensors:  54% 1.85G/3.44G [00:51<00:42, 37.8MB/s]
# model.safetensors:  54% 1.86G/3.44G [00:51<00:46, 34.5MB/s]
# model.safetensors:  54% 1.87G/3.44G [00:51<00:32, 48.3MB/s]
# model.safetensors:  55% 1.88G/3.44G [00:52<00:35, 43.5MB/s]
# model.safetensors:  55% 1.89G/3.44G [00:52<00:45, 34.4MB/s]
# model.safetensors:  55% 1.90G/3.44G [00:52<00:32, 47.9MB/s]
# model.safetensors:  56% 1.91G/3.44G [00:52<00:40, 37.9MB/s]
# model.safetensors:  56% 1.92G/3.44G [00:53<00:45, 33.7MB/s]
# model.safetensors:  56% 1.93G/3.44G [00:53<00:32, 47.0MB/s]
# model.safetensors:  56% 1.94G/3.44G [00:53<00:36, 41.3MB/s]
# model.safetensors:  57% 1.95G/3.44G [00:54<00:45, 33.0MB/s]
# model.safetensors:  57% 1.97G/3.44G [00:54<00:32, 46.0MB/s]
# model.safetensors:  57% 1.97G/3.44G [00:54<00:36, 40.0MB/s]
# model.safetensors:  58% 1.98G/3.44G [00:54<00:39, 36.5MB/s]
# model.safetensors:  58% 2.00G/3.44G [00:54<00:28, 50.2MB/s]
# model.safetensors:  58% 2.01G/3.44G [00:55<00:35, 41.0MB/s]
# model.safetensors:  59% 2.02G/3.44G [00:55<00:39, 36.0MB/s]
# model.safetensors:  59% 2.03G/3.44G [00:55<00:28, 49.8MB/s]
# model.safetensors:  59% 2.04G/3.44G [00:55<00:34, 40.7MB/s]
# model.safetensors:  60% 2.05G/3.44G [00:56<00:37, 37.4MB/s]
# model.safetensors:  60% 2.06G/3.44G [00:56<00:26, 51.3MB/s]
# model.safetensors:  60% 2.07G/3.44G [00:56<00:32, 41.7MB/s]
# model.safetensors:  60% 2.08G/3.44G [00:57<00:36, 37.3MB/s]
# model.safetensors:  61% 2.10G/3.44G [00:57<00:25, 52.0MB/s]
# model.safetensors:  61% 2.10G/3.44G [00:57<00:31, 42.0MB/s]
# model.safetensors:  61% 2.11G/3.44G [00:57<00:36, 36.9MB/s]
# model.safetensors:  62% 2.13G/3.44G [00:57<00:25, 50.8MB/s]
# model.safetensors:  62% 2.13G/3.44G [00:58<00:29, 44.9MB/s]
# model.safetensors:  62% 2.14G/3.44G [00:58<00:31, 41.0MB/s]
# model.safetensors:  63% 2.16G/3.44G [00:58<00:22, 55.8MB/s]
# model.safetensors:  63% 2.17G/3.44G [00:58<00:29, 42.7MB/s]
# model.safetensors:  63% 2.18G/3.44G [00:59<00:34, 36.6MB/s]
# model.safetensors:  64% 2.19G/3.44G [00:59<00:24, 50.3MB/s]
# model.safetensors:  64% 2.20G/3.44G [00:59<00:27, 45.6MB/s]
# model.safetensors:  64% 2.21G/3.44G [00:59<00:31, 39.7MB/s]
# model.safetensors:  65% 2.22G/3.44G [01:00<00:22, 54.0MB/s]
# model.safetensors:  65% 2.23G/3.44G [01:00<00:30, 39.6MB/s]
# model.safetensors:  65% 2.24G/3.44G [01:00<00:31, 37.7MB/s]
# model.safetensors:  66% 2.25G/3.44G [01:00<00:22, 51.7MB/s]
# model.safetensors:  66% 2.26G/3.44G [01:01<00:25, 46.3MB/s]
# model.safetensors:  66% 2.27G/3.44G [01:01<00:32, 35.6MB/s]
# model.safetensors:  66% 2.29G/3.44G [01:01<00:23, 49.2MB/s]
# model.safetensors:  67% 2.29G/3.44G [01:01<00:27, 41.1MB/s]
# model.safetensors:  67% 2.30G/3.44G [01:02<00:32, 35.5MB/s]
# model.safetensors:  67% 2.32G/3.44G [01:02<00:22, 49.1MB/s]
# model.safetensors:  68% 2.33G/3.44G [01:02<00:29, 38.1MB/s]
# model.safetensors:  68% 2.34G/3.44G [01:03<00:33, 33.2MB/s]
# model.safetensors:  68% 2.35G/3.44G [01:03<00:23, 46.2MB/s]
# model.safetensors:  69% 2.36G/3.44G [01:03<00:30, 35.6MB/s]
# model.safetensors:  69% 2.37G/3.44G [01:03<00:32, 33.3MB/s]
# model.safetensors:  69% 2.38G/3.44G [01:04<00:22, 46.6MB/s]
# model.safetensors:  69% 2.39G/3.44G [01:04<00:25, 40.8MB/s]
# model.safetensors:  70% 2.40G/3.44G [01:04<00:30, 34.5MB/s]
# model.safetensors:  70% 2.41G/3.44G [01:04<00:21, 48.0MB/s]
# model.safetensors:  70% 2.42G/3.44G [01:05<00:25, 39.3MB/s]
# model.safetensors:  71% 2.43G/3.44G [01:05<00:28, 35.7MB/s]
# model.safetensors:  71% 2.45G/3.44G [01:05<00:20, 49.4MB/s]
# model.safetensors:  71% 2.45G/3.44G [01:05<00:22, 44.3MB/s]
# model.safetensors:  72% 2.46G/3.44G [01:06<00:25, 37.6MB/s]
# model.safetensors:  72% 2.48G/3.44G [01:06<00:18, 51.9MB/s]
# model.safetensors:  72% 2.49G/3.44G [01:06<00:22, 42.0MB/s]
# model.safetensors:  73% 2.50G/3.44G [01:06<00:24, 38.9MB/s]
# model.safetensors:  73% 2.51G/3.44G [01:06<00:17, 53.2MB/s]
# model.safetensors:  73% 2.52G/3.44G [01:07<00:22, 40.4MB/s]
# model.safetensors:  73% 2.53G/3.44G [01:07<00:26, 34.9MB/s]
# model.safetensors:  74% 2.54G/3.44G [01:07<00:18, 48.5MB/s]
# model.safetensors:  74% 2.55G/3.44G [01:08<00:21, 41.0MB/s]
# model.safetensors:  74% 2.56G/3.44G [01:08<00:23, 37.0MB/s]
# model.safetensors:  75% 2.57G/3.44G [01:08<00:17, 50.8MB/s]
# model.safetensors:  75% 2.58G/3.44G [01:08<00:20, 41.1MB/s]
# model.safetensors:  75% 2.59G/3.44G [01:09<00:23, 36.1MB/s]
# model.safetensors:  76% 2.61G/3.44G [01:09<00:16, 50.2MB/s]
# model.safetensors:  76% 2.61G/3.44G [01:09<00:21, 37.9MB/s]
# model.safetensors:  76% 2.62G/3.44G [01:09<00:22, 36.7MB/s]
# model.safetensors:  77% 2.64G/3.44G [01:10<00:15, 50.5MB/s]
# model.safetensors:  77% 2.65G/3.44G [01:10<00:17, 45.4MB/s]
# model.safetensors:  77% 2.66G/3.44G [01:10<00:19, 40.0MB/s]
# model.safetensors:  78% 2.67G/3.44G [01:10<00:14, 54.4MB/s]
# model.safetensors:  78% 2.68G/3.44G [01:11<00:21, 36.2MB/s]
# model.safetensors:  78% 2.69G/3.44G [01:11<00:23, 32.2MB/s]
# model.safetensors:  79% 2.70G/3.44G [01:11<00:16, 44.9MB/s]
# model.safetensors:  79% 2.71G/3.44G [01:11<00:18, 40.0MB/s]
# model.safetensors:  79% 2.72G/3.44G [01:12<00:19, 36.4MB/s]
# model.safetensors:  79% 2.73G/3.44G [01:12<00:14, 50.3MB/s]
# model.safetensors:  80% 2.74G/3.44G [01:12<00:15, 46.3MB/s]
# model.safetensors:  80% 2.75G/3.44G [01:12<00:16, 42.7MB/s]
# model.safetensors:  80% 2.77G/3.44G [01:12<00:11, 58.4MB/s]
# model.safetensors:  81% 2.78G/3.44G [01:13<00:14, 47.4MB/s]
# model.safetensors:  81% 2.78G/3.44G [01:13<00:17, 37.7MB/s]
# model.safetensors:  81% 2.80G/3.44G [01:13<00:12, 51.8MB/s]
# model.safetensors:  82% 2.81G/3.44G [01:16<00:54, 11.7MB/s]
# model.safetensors:  82% 2.82G/3.44G [01:16<00:48, 12.8MB/s]
# model.safetensors:  82% 2.83G/3.44G [01:16<00:31, 19.3MB/s]
# model.safetensors:  82% 2.84G/3.44G [01:17<00:29, 20.8MB/s]
# model.safetensors:  83% 2.85G/3.44G [01:17<00:25, 23.1MB/s]
# model.safetensors:  83% 2.86G/3.44G [01:17<00:17, 33.7MB/s]
# model.safetensors:  83% 2.87G/3.44G [01:17<00:18, 31.1MB/s]
# model.safetensors:  84% 2.88G/3.44G [01:18<00:19, 28.4MB/s]
# model.safetensors:  84% 2.89G/3.44G [01:18<00:13, 40.5MB/s]
# model.safetensors:  84% 2.90G/3.44G [01:18<00:15, 34.1MB/s]
# model.safetensors:  85% 2.91G/3.44G [01:19<00:16, 31.4MB/s]
# model.safetensors:  85% 2.93G/3.44G [01:19<00:11, 44.2MB/s]
# model.safetensors:  85% 2.93G/3.44G [01:19<00:13, 36.8MB/s]
# model.safetensors:  86% 2.94G/3.44G [01:19<00:14, 34.3MB/s]
# model.safetensors:  86% 2.96G/3.44G [01:20<00:10, 47.7MB/s]
# model.safetensors:  86% 2.97G/3.44G [01:20<00:10, 44.2MB/s]
# model.safetensors:  86% 2.98G/3.44G [01:20<00:15, 29.8MB/s]
# model.safetensors:  87% 2.99G/3.44G [01:20<00:10, 42.7MB/s]
# model.safetensors:  87% 3.00G/3.44G [01:21<00:15, 28.1MB/s]
# model.safetensors:  87% 3.01G/3.44G [01:22<00:26, 16.2MB/s]
# model.safetensors:  88% 3.02G/3.44G [01:22<00:17, 24.2MB/s]
# model.safetensors:  88% 3.03G/3.44G [01:23<00:16, 25.3MB/s]
# model.safetensors:  88% 3.04G/3.44G [01:23<00:15, 25.7MB/s]
# model.safetensors:  89% 3.05G/3.44G [01:23<00:10, 36.8MB/s]
# model.safetensors:  89% 3.06G/3.44G [01:23<00:11, 32.7MB/s]
# model.safetensors:  89% 3.07G/3.44G [01:24<00:11, 32.6MB/s]
# model.safetensors:  90% 3.09G/3.44G [01:24<00:07, 45.5MB/s]
# model.safetensors:  90% 3.09G/3.44G [01:24<00:08, 39.5MB/s]
# model.safetensors:  90% 3.10G/3.44G [01:25<00:09, 33.9MB/s]
# model.safetensors:  91% 3.12G/3.44G [01:25<00:06, 47.2MB/s]
# model.safetensors:  91% 3.13G/3.44G [01:25<00:07, 41.7MB/s]
# model.safetensors:  91% 3.14G/3.44G [01:25<00:08, 36.8MB/s]
# model.safetensors:  92% 3.15G/3.44G [01:25<00:05, 50.7MB/s]
# model.safetensors:  92% 3.16G/3.44G [01:26<00:09, 31.4MB/s]
# model.safetensors:  92% 3.17G/3.44G [01:26<00:08, 31.3MB/s]
# model.safetensors:  92% 3.18G/3.44G [01:26<00:05, 44.1MB/s]
# model.safetensors:  93% 3.19G/3.44G [01:27<00:05, 42.0MB/s]
# model.safetensors:  93% 3.20G/3.44G [01:27<00:06, 35.2MB/s]
# model.safetensors:  93% 3.21G/3.44G [01:27<00:04, 48.7MB/s]
# model.safetensors:  94% 3.22G/3.44G [01:27<00:05, 40.2MB/s]
# model.safetensors:  94% 3.23G/3.44G [01:28<00:05, 38.0MB/s]
# model.safetensors:  94% 3.25G/3.44G [01:28<00:03, 52.1MB/s]
# model.safetensors:  95% 3.25G/3.44G [01:28<00:04, 41.5MB/s]
# model.safetensors:  95% 3.26G/3.44G [01:28<00:04, 37.3MB/s]
# model.safetensors:  95% 3.28G/3.44G [01:29<00:03, 51.1MB/s]
# model.safetensors:  95% 3.29G/3.44G [01:29<00:03, 41.7MB/s]
# model.safetensors:  96% 3.30G/3.44G [01:29<00:03, 36.5MB/s]
# model.safetensors:  96% 3.31G/3.44G [01:29<00:02, 50.9MB/s]
# model.safetensors:  96% 3.32G/3.44G [01:30<00:02, 41.8MB/s]
# model.safetensors:  97% 3.33G/3.44G [01:30<00:03, 36.3MB/s]
# model.safetensors:  97% 3.34G/3.44G [01:30<00:01, 50.2MB/s]
# model.safetensors:  97% 3.35G/3.44G [01:30<00:02, 42.6MB/s]
# model.safetensors:  98% 3.36G/3.44G [01:31<00:02, 37.5MB/s]
# model.safetensors:  98% 3.37G/3.44G [01:31<00:01, 51.3MB/s]
# model.safetensors:  98% 3.38G/3.44G [01:31<00:01, 41.0MB/s]
# model.safetensors:  99% 3.39G/3.44G [01:31<00:01, 37.9MB/s]
# model.safetensors:  99% 3.41G/3.44G [01:32<00:00, 52.2MB/s]
# model.safetensors:  99% 3.41G/3.44G [01:32<00:00, 38.9MB/s]
# model.safetensors:  99% 3.42G/3.44G [01:32<00:00, 36.9MB/s]
# model.safetensors: 100% 3.44G/3.44G [01:33<00:00, 36.9MB/s]
#
#
#
#
#
# Upload 30 LFS files: 100% 30/30 [01:33<00:00,  3.12s/it]
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:02,  2.51it/s]{'force_upcast', 'scaling_factor'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  43% 3/7 [00:00<00:01,  3.95it/s]{'time_embedding_type', 'class_embed_type', 'projection_class_embeddings_input_dim', 'class_embeddings_concat', 'num_class_embeds', 'conv_out_kernel', 'encoder_hid_dim', 'dropout', 'num_attention_heads', 'addition_embed_type', 'attention_type', 'dual_cross_attention', 'use_linear_projection', 'addition_embed_type_num_heads', 'reverse_transformer_layers_per_block', 'upcast_attention', 'only_cross_attention', 'time_embedding_dim', 'addition_time_embed_dim', 'mid_block_type', 'transformer_layers_per_block', 'mid_block_only_cross_attention', 'time_cond_proj_dim', 'encoder_hid_dim_type', 'resnet_out_scale_factor', 'resnet_time_scale_shift', 'timestep_post_act', 'cross_attention_norm', 'time_embedding_act_fn', 'conv_in_kernel', 'resnet_skip_time_act'} was not found in config. Values will be initialized to default values.
# Loaded unet as UNet2DConditionModel from `unet` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:00<00:00,  4.59it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  6.85it/s]
#
#   0% 0/30 [00:00<?, ?it/s]
#   3% 1/30 [00:00<00:07,  3.70it/s]
#   7% 2/30 [00:00<00:05,  5.22it/s]
#  10% 3/30 [00:00<00:04,  5.99it/s]
#  13% 4/30 [00:00<00:04,  6.42it/s]
#  17% 5/30 [00:00<00:03,  6.71it/s]
#  20% 6/30 [00:00<00:03,  6.91it/s]
#  23% 7/30 [00:01<00:03,  7.03it/s]
#  27% 8/30 [00:01<00:03,  7.10it/s]
#  30% 9/30 [00:01<00:02,  7.15it/s]
#  33% 10/30 [00:01<00:02,  7.17it/s]
#  37% 11/30 [00:01<00:02,  7.21it/s]
#  40% 12/30 [00:01<00:02,  7.24it/s]
#  43% 13/30 [00:01<00:02,  7.25it/s]
#  47% 14/30 [00:02<00:02,  7.23it/s]
#  50% 15/30 [00:02<00:02,  7.22it/s]
#  53% 16/30 [00:02<00:01,  7.24it/s]
#  57% 17/30 [00:02<00:01,  7.26it/s]
#  60% 18/30 [00:02<00:01,  7.27it/s]
#  63% 19/30 [00:02<00:01,  7.25it/s]
#  67% 20/30 [00:02<00:01,  7.24it/s]
#  70% 21/30 [00:03<00:01,  7.24it/s]
#  73% 22/30 [00:03<00:01,  7.24it/s]
#  77% 23/30 [00:03<00:00,  7.24it/s]
#  80% 24/30 [00:03<00:00,  7.25it/s]
#  83% 25/30 [00:03<00:00,  7.25it/s]
#  87% 26/30 [00:03<00:00,  7.24it/s]
#  90% 27/30 [00:03<00:00,  7.24it/s]
#  93% 28/30 [00:03<00:00,  7.24it/s]
#  97% 29/30 [00:04<00:00,  7.25it/s]
# 100% 30/30 [00:04<00:00,  7.03it/s]
#
#   0% 0/30 [00:00<?, ?it/s]
#   3% 1/30 [00:00<00:08,  3.60it/s]
#   7% 2/30 [00:00<00:05,  5.07it/s]
#  10% 3/30 [00:00<00:04,  5.84it/s]
#  13% 4/30 [00:00<00:04,  6.34it/s]
#  17% 5/30 [00:00<00:03,  6.65it/s]
#  20% 6/30 [00:00<00:03,  6.84it/s]
#  23% 7/30 [00:01<00:03,  6.95it/s]
#  27% 8/30 [00:01<00:03,  7.01it/s]
#  30% 9/30 [00:01<00:02,  7.08it/s]
#  33% 10/30 [00:01<00:02,  7.13it/s]
#  37% 11/30 [00:01<00:02,  7.17it/s]
#  40% 12/30 [00:01<00:02,  7.20it/s]
#  43% 13/30 [00:01<00:02,  7.22it/s]
#  47% 14/30 [00:02<00:02,  7.21it/s]
#  50% 15/30 [00:02<00:02,  7.22it/s]
#  53% 16/30 [00:02<00:01,  7.22it/s]
#  57% 17/30 [00:02<00:01,  7.23it/s]
#  60% 18/30 [00:02<00:01,  7.24it/s]
#  63% 19/30 [00:02<00:01,  7.26it/s]
#  67% 20/30 [00:02<00:01,  7.26it/s]
#  70% 21/30 [00:03<00:01,  7.25it/s]
#  73% 22/30 [00:03<00:01,  7.22it/s]
#  77% 23/30 [00:03<00:00,  7.22it/s]
#  80% 24/30 [00:03<00:00,  7.22it/s]
#  83% 25/30 [00:03<00:00,  7.21it/s]
#  87% 26/30 [00:03<00:00,  7.23it/s]
#  90% 27/30 [00:03<00:00,  7.26it/s]
#  93% 28/30 [00:04<00:00,  7.26it/s]
#  97% 29/30 [00:04<00:00,  7.26it/s]
# 100% 30/30 [00:04<00:00,  7.00it/s]
#
#   0% 0/30 [00:00<?, ?it/s]
#   3% 1/30 [00:00<00:07,  3.66it/s]
#   7% 2/30 [00:00<00:05,  5.16it/s]
#  10% 3/30 [00:00<00:04,  5.92it/s]
#  13% 4/30 [00:00<00:04,  6.37it/s]
#  17% 5/30 [00:00<00:03,  6.65it/s]
#  20% 6/30 [00:00<00:03,  6.83it/s]
#  23% 7/30 [00:01<00:03,  6.96it/s]
#  27% 8/30 [00:01<00:03,  7.06it/s]
#  30% 9/30 [00:01<00:02,  7.12it/s]
#  33% 10/30 [00:01<00:02,  7.14it/s]
#  37% 11/30 [00:01<00:02,  7.13it/s]
#  40% 12/30 [00:01<00:02,  7.15it/s]
#  43% 13/30 [00:01<00:02,  7.17it/s]
#  47% 14/30 [00:02<00:02,  7.21it/s]
#  50% 15/30 [00:02<00:02,  7.24it/s]
#  53% 16/30 [00:02<00:01,  7.24it/s]
#  57% 17/30 [00:02<00:01,  7.20it/s]
#  60% 18/30 [00:02<00:01,  7.19it/s]
#  63% 19/30 [00:02<00:01,  7.19it/s]
#  67% 20/30 [00:02<00:01,  7.19it/s]
#  70% 21/30 [00:03<00:01,  7.20it/s]
#  73% 22/30 [00:03<00:01,  7.22it/s]
#  77% 23/30 [00:03<00:00,  7.21it/s]
#  80% 24/30 [00:03<00:00,  7.22it/s]
#  83% 25/30 [00:03<00:00,  7.24it/s]
#  87% 26/30 [00:03<00:00,  7.22it/s]
#  90% 27/30 [00:03<00:00,  7.20it/s]
#  93% 28/30 [00:04<00:00,  7.20it/s]
#  97% 29/30 [00:04<00:00,  7.19it/s]
# 100% 30/30 [00:04<00:00,  6.99it/s]
#
#   0% 0/30 [00:00<?, ?it/s]
#   3% 1/30 [00:00<00:07,  3.66it/s]
#   7% 2/30 [00:00<00:05,  5.15it/s]
#  10% 3/30 [00:00<00:04,  5.90it/s]
#  13% 4/30 [00:00<00:04,  6.35it/s]
#  17% 5/30 [00:00<00:03,  6.63it/s]
#  20% 6/30 [00:00<00:03,  6.83it/s]
#  23% 7/30 [00:01<00:03,  6.94it/s]
#  27% 8/30 [00:01<00:03,  7.02it/s]
#  30% 9/30 [00:01<00:02,  7.08it/s]
#  33% 10/30 [00:01<00:02,  7.14it/s]
#  37% 11/30 [00:01<00:02,  7.19it/s]
#  40% 12/30 [00:01<00:02,  7.21it/s]
#  43% 13/30 [00:01<00:02,  7.22it/s]
#  47% 14/30 [00:02<00:02,  7.22it/s]
#  50% 15/30 [00:02<00:02,  7.22it/s]
#  53% 16/30 [00:02<00:01,  7.21it/s]
#  57% 17/30 [00:02<00:01,  7.22it/s]
#  60% 18/30 [00:02<00:01,  7.23it/s]
#  63% 19/30 [00:02<00:01,  7.23it/s]
#  67% 20/30 [00:02<00:01,  7.20it/s]
#  70% 21/30 [00:03<00:01,  7.19it/s]
#  73% 22/30 [00:03<00:01,  7.20it/s]
#  77% 23/30 [00:03<00:00,  7.21it/s]
#  80% 24/30 [00:03<00:00,  7.20it/s]
#  83% 25/30 [00:03<00:00,  7.19it/s]
#  87% 26/30 [00:03<00:00,  7.19it/s]
#  90% 27/30 [00:03<00:00,  7.21it/s]
#  93% 28/30 [00:04<00:00,  7.21it/s]
#  97% 29/30 [00:04<00:00,  7.20it/s]
# 100% 30/30 [00:04<00:00,  6.98it/s]
# Steps: 100% 800/800 [1:38:24<00:00,  7.38s/it, lr=0, step_loss=0.00803]

# %% [markdown]
# Download and setup base model and lora adapter for check

# %%
# Stable Diffusion V1
from diffusers import StableDiffusionPipeline
import torch
from PIL import Image

lora_path = "jwl25b/testModelSDv1-2"
model_path = 'runwayml/stable-diffusion-v1-5'
pipe = StableDiffusionPipeline.from_pretrained(model_path, torch_dtype=torch.float16)

#This setup is for lora model.
pipe.unet.load_attn_procs(lora_path)

#Turn off safety checker
#pipe.safety_checker = lambda images, **kwargs: (images, [False] * len(images))

pipe.to("cuda")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# pytorch_lora_weights.safetensors:   0%|          | 0.00/3.23M [00:00<?, ?B/s]
# StableDiffusionPipeline {
#   "_class_name": "StableDiffusionPipeline",
#   "_diffusers_version": "0.25.0.dev0",
#   "_name_or_path": "runwayml/stable-diffusion-v1-5",
#   "feature_extractor": [
#     "transformers",
#     "CLIPImageProcessor"
#   ],
#   "image_encoder": [
#     null,
#     null
#   ],
#   "requires_safety_checker": true,
#   "safety_checker": [
#     "stable_diffusion",
#     "StableDiffusionSafetyChecker"
#   ],
#   "scheduler": [
#     "diffusers",
#     "PNDMScheduler"
#   ],
#   "text_encoder": [
#     "transformers",
#     "CLIPTextModel"
#   ],
#   "tokenizer": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DConditionModel"
#   ],
#   "vae": [
#     "diffusers",
#     "AutoencoderKL"
#   ]
# }

# %%
# Run inference using prompts to acquire 4 image panels
image1 = pipe(prompt="Quarter-Zip V-Neck Black Sweatshirt with Tommy Logo at the chest").images[0]
image1.save("productImage1.png")

image2 = pipe(prompt="Solid Crewneck Navy Blue Crewneck polo with signature stripe tipping").images[0]
image2.save("productImage2.png")

image3 = pipe(prompt="Embroidered Tommy Logo Green T-Shirt with textured boxy knit").images[0]
image3.save("productImage3.png")

image4 = pipe(prompt="Slim Fit Stripe Classic White Polo with Tommy Flag Logo").images[0]
image4.save("productImage4.png")

# Image grid helper function from HuggingFace
def image_grid(imgs, rows, cols):
    assert len(imgs) == rows*cols

    w, h = imgs[0].size
    grid = Image.new('RGB', size=(cols*w, rows*h))
    grid_w, grid_h = grid.size

    for i, img in enumerate(imgs):
        grid.paste(img, box=(i%cols*w, i//cols*h))
    return grid

all_images = [image1, image2, image3, image4]
grid = image_grid(all_images, rows=1, cols=4)
grid
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=2048x512>
