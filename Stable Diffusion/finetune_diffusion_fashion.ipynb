# %%
# !cd /content/
# !git clone https://github.com/huggingface/diffusers.git
# !pip install ./diffusers
# !pip install -U -r /content/diffusers/examples/text_to_image/requirements.txt
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 48355, done.
# remote: Counting objects: 100% (13174/13174), done.
# remote: Compressing objects: 100% (903/903), done.
# remote: Total 48355 (delta 12712), reused 12376 (delta 12221), pack-reused 35181
# Receiving objects: 100% (48355/48355), 31.43 MiB | 13.50 MiB/s, done.
# Resolving deltas: 100% (35991/35991), done.
# Processing ./diffusers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for diffusers: filename=diffusers-0.25.0.dev0-py3-none-any.whl size=1821788 sha256=27138c2a5f6c28d5a81b2d812f2096b602373bc2f1847f318a36b7253b40104b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-srtdv5kz/wheels/95/c5/3b/e1b4269f8a2584de57e75f949a185b48fc4144e9a91fc9965a
# Successfully built diffusers
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 4.5 MB/s eta 0:00:00
# ...

# %%
# !nvidia-smi
# Out:
# Sun Dec 17 16:54:04 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !accelerate config default --mixed_precision fp16
# Out:
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !cp /content/train_text_to_image.py /content/diffusers/examples/text_to_image/train_text_to_image.py

# %%
# !accelerate launch diffusers/examples/text_to_image/train_text_to_image.py \
--pretrained_model_name_or_path="OFA-Sys/small-stable-diffusion-v0" --dataset_name="jwl25b/final_project_dataset" \
 --resolution=512 --train_batch_size=16 --validation_prompts="Tommy Hilfiger men's Regular Fit Round Logo Grey Polo" \
 --gradient_accumulation_steps=2 --gradient_checkpointing --mixed_precision="fp16" \
 --max_train_steps=1200 --learning_rate=1e-05 --max_grad_norm=1 --checkpointing_steps=10000 \
 --push_to_hub --hub_token="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" \
 --lr_scheduler="constant" --lr_warmup_steps=0 --output_dir="small-stable-diffusion-v0-th-1200-e5-g2-bs16" --caption_column="text"
